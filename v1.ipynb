# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Tamil_lyrics_v1.csv")

# %%
ar_df = df[(df["music_director"] == "A.R.Rahman") & (df["year"] > 2000)]
cols = ['lyricist', 'movie', 'song_name', 'year',
       'lyrics_english', 'lyrics_tamil', 'music_director', 'link']
ar_df = ar_df[cols][:120]

# %% [markdown]
# ### Modify

# %%
ar_df["lyricist"] = ar_df["lyricist"].map({"Vaali": "வாலி", "Vairamuthu": "வைரமுத்து"})
ar_df["music_director"] = ar_df["music_director"].map({"A.R.Rahman": "ஏ. ஆர். ரகுமான்"})
ar_df["movie"] = ar_df["movie"].map(
    {
        "Ambikapathy": "ராஞ்சனா",
        "Kochadaiiyaan": "கோச்சடையான்",              
        "Guru":"குரு",                       
        "Aaytha Ezhuthu":"ஆய்த எழுத்து",             
        "New":"புதிய",                        
        "Desam":"தேசம்",                      
        "Varalaaru":"வரலாறு",                  
        "Kannathil Muthamittal":"கன்னத்தில் முத்தமிட்",      
        "Paarthale Paravasam":"பார்த்தாலே பரவசம்",       
        "Anbe Aaruyire": "அன்பே ஆருயிரே",             
        "Kadhal Virus":"காதல் வைரஸ்",               
        "Baba":"பாபா",                       
        "Raavanan":"ராவணன்",                   
        "O Kadhal Kanmani":"ஓ காதல் கண்மணி",           
        "Sivaji":"சிவாஜி",                     
        "Lingaa":"லிங்கா",                     
        "Alli Arjuna":"அல்லி அர்ஜுனா",                
        "Enthiran":"எந்திரன்",                   
        "Star":"நட்சத்திரம்",                       
        "Boys":"பாய்ஸ்",                       
        "Maryan":"மரியான்",                     
        "Kaatru Veliyidai":"காற்று வெளியிடை",         
        "Chekka Chivantha Vaanam":"செக்கச்சிவந்த வானம்",   
        "24":"24",                         
        "Kadal":"கடல்",                      
        "Azhagiya Tamil Magan":"அழகிய தமிழ்மகன்",       
        "Sakkarakatti":"சக்கரகட்டி",               
        "Kaaviya Thalaivan":"காவியத் தலைவன்",          
        "Parasuram":"பரசுராம்",                
    })

ar_df["song_name"] = ar_df["song_name"].map({
    "Adhisaya Thirumanam " : "அதிசய திருமணம்",
"Marudhani Marudhani " : "மருதாணி மருதாணி",
"Manmadha Masam " : "மன்மத மாசம்",
"Moondrezhuthu " : "மூன்றெழுத்து",
"Nee Thaan En Desiya Geetham" : "நீதான் என் தேசிய கீதம்",
"Anbe Aaruyire " : "அன்பே ஆருயிரே",
"Athiradee " : "அதிரடிக்காரன்",
"Maram Kothiye" : "மரம் கொத்தியே",
"Ellappugazhum Oruvan Oruvanukke " : "எல்லாப் புகழும் ஒருவன் ஒருவனுக்கே",
"Mayiliragae" : "மயிலிறகே",
"Alli Arjuna " : "அல்லி அர்ஜுனன்",
"Bailamore " : "பைலாமோர்",
"Thazhuvudu" : "தழுவுது",
"Enthan Vanil " : "எந்தன் வானின்",
"Thigu Thigu " : "திகு திகு",
"Medhuvaagathaan" : "மெதுவாக தான்",
"Kaaviriya Kaaviriya " : "காவிரியா காவிரியா",
"Varugiraai " : "வருகிறாய்",
"If You Wanna" : "இப் யூ வான்னா",
"Kettenaa Naan " : "கேட்டேனா",
"Naetru Aval " : "நேற்று அவள்",
"Maro Maro " : "மாரோ மாரோ",
"Kalayil Dhinamum " : "காலையில் தினமும்",
"Maya Maya" : "மாயா மாயா",
"Kumbakonam Santhayile " : "கும்பக்கோணம் சந்தையிலே",
"Sonapareeya " : "சொன்னபரியா…",
"Mazhai Mega Vanna " : "மழை மேக வண்ணா",
"O Kadhale " : "ஓ காதலே",
"Please Sir Please Sir " : "ப்ளீஸ் சார் ப்ளீஸ் சார்",
"Rajyama Illai Emaiyama " : "ராஜ்யமா இல்லை இமயமா",
"New New" : "நியூ நியூ",
"Sakkarai " : "சக்கரை",
"Secret of Success " : "வெற்றியின் ரகசியமே",
"Thottal Poo Malarum " : "தொட்டால் பூ மலரும்",
"Sonnalum" : "சொன்னாலும்",
"Thaai Sonna" : "தாய் சொன்ன",
"Unnai Kelaai " : "உன்னை கேளாய்",
"Unthan Desathin Kural" : "உந்தன் தேசத்தின் குரல்",
"Vaan Nila" : "வான் நிலா",
"Oru Deivam Thantha Poove (Female) " : "ஒரு தெய்வம் தந்த பூவே",
"Oru Deivam Thantha Poove (Male) " : "ஒரு தெய்வம் தந்த பூவே",
"Sakthi Kodu" : "சக்தி கொடு",
"Sattena Nenaindhadhu Nenjam " : "சட்டென நனைந்தது நெஞ்சம்",
"Aaruyire Mannipaaya " : "ஆருயிரே மன்னிப்பாயா",
"Sundari Siriya Rettai Vaal" : "சுந்தரி சிறிய ரெட்டை வால்",
"Mayya Mayya " : "மையா மையா",
"Nannare Nannare " : "நன்னநாரே நன்னநாரே",
"Ore Kana " : "ஒரே கனா",
"Paisaa Paisaa " : "பைசா பைசா",
"Rendu Manga " : "ரெண்டு மாங்கா",
"Sahana Saral " : "சஹானா சாரல்",
"Sahara " : "சஹாரா",
"Vellai Pookal " : "வெள்ளை பூக்கள்",
"Vaaji Vaaji" : "வாஜி வாஜி",
"Vidai Kodu Engal Naadae " : "விடை கொடு எங்கள் நாடே",
"Azhagae Sugama " : "அழகே சுகமா",
"Azhagae Sugama 2 " : "அழகே சுகமா",
"Endhan Nenjil " : "எந்தன் நெஞ்சில்",
"Arima Arima " : "அரிமா அரிமா",
"Kaattu Sirukki " : "காட்டுச் சிறுக்கி",
"Kadhal Anukkal " : "காதல் அணுக்கள்",
"Machcha Machchiniye " : "மச்ச மச்சினியே",
"Kalvare Kalvare " : "கள்வரே கள்வரே",
"Manasukkul Oru Puyal " : "மனசுக்குள் ஒரு புயல்",
"Keda Keda Kari" : "கெடா கெடா கறி",
"Pudhiya Manidha " : "புதிய மனிதா",
"Osaka Muraiya " : "ஒசாக்கா முறையா",
"Usure Pogudhey " : "உசுரே போகுதே",
"En Mannava " : "என் மன்னவா",
"Engae Pogudho Vaanam " : "எங்கே போகுதோ வானம்",
"Nee Mazhai " : "நீ மழை",
"Engal Kochadaiyaan " : "எங்கள் கோச்சடையான்",
"Ye Manpuru Mangaye" : "ஏய் மான்புரு மங்கையே",
"Shingu Lingu Lala " : "ஷிங்கு லிங்கு லாலா",
"Idhayam " : "இதயம்",
"Nenjam Ellam " : "நெஞ்சம் எல்லாம்",
"Indiane Vaa " : "இந்தியனே வா",
"Sollayo Solai Kili " : "சொல்லாயோ சோலைக் கிளி",
"Karma Veeran " : "கர்ம வீரனே",
"Dippu Dippu " : "டிப்பு டிப்பு",
"Sandakkozhi" : "சண்ட கோழி",
"Spiderman " : "ஸ்பைடர்மேன்",
"Thom Karuvil Irunthom " : "தோம் கருவில் இருந்தோ",
"Maatram Ondruthaan Maarathathu" : "மாற்றம் ஒன்று தான் மாறாதது",
"Manamaganin Sathiyam " : "சத்தியம் சத்தியம்",
"Ilamai Vidugathai " : "இளமை விடுகதை",
"Manappennin Sathiyam" : "காதல் கணவா உந்தன்",
"InnisaInnisai Alapedaye " : "இன்னிசை அளபெடையே",
"Oh Nanba " : "ஓ நண்பா",
"Kaatril Or Varthai " : "காற்றில் ஓர் வார்தை",
"Kichu Kichu Tha " : "கிச்சு கிச்சு தா",
"Yaakai Thiri " : "யாக்கை திரி",
"Kamma Karaiyil Song Lyrics" : "கம்மா கரையிலே",
"Unmai Orunaal Vellum " : "உண்மை ஒருநாள் வெல்லும்",
"En Jeevane " : "என் ஜீவனே",
"Ambikapathy " : "ஓ… கங்கையிலே",
"Tango Kelaayo" : "கேளாயோ கேளாயோ",
"Hey Goodbye Nanba " : "ஹே குட்பை நண்பா",
"Jana Gana Mana " : "ஜன கன மன",
"Muppadhu Nimidam " : "முப்பது நிமிடம்",
"Vaan Varuvaan " : "வான் வருவான்",
"Kalaarasiga " : "கலா ரசிகா",
"Bhoomi Bhoomi" : "பூமி… பூமி…",
"Kanaave Kanaave " : "கனவே கனவே",
"Theeyil Vizhundha " : "தீயில் விழுந்த",
"Kaalam En Kadhali" : "காலம் என் காதலியோ",
"Punnagaye " : "புன்னகையே…",
"Thottapuram " : "தொத்தாபுரம்",
"Oliyaaga Vandhaai " : "ஒளியாக வந்தாய்",
"Mazhai Kuruvi" : "மழை குருவி",
"Aye Sinamika " : "யே சினாமிகா",
"Paarkaadhey Oru Madhiri " : "பார்காதே ஒரு மாதிரி…",
"Parakka Seivaai " : "பறக செய்வாய்",
"Kaara Aattakkaara " : "காரா ஆட்டக்காரா",
"Solvadhai Seidhu Mudippom " : "சொன்னதை செய்து முடிப்போம்",
"Naane Varugiren Song Lyrics" : "நானே வருகிறேன்",
"Unnaal Unnaal " : "உன்னால் உன்னால",
"Parandhu Sella Vaa " : "பறந்து செல்ல வா",
"Chithirai Nela " : "சித்திரை நிலா",
"Moongil Thottam " : "மூங்கில் தோட்டோ",
})

# %% [markdown]
# ### Metaphors

# %%
ar_df = pd.read_csv("arr+tamil_v2.csv")

# %%
for row in ar_df.iterrows():
    print(f"{row[0]}")
    print(f"{row[1]['song_name']} - {row[1]['lyrics_tamil']}")
    print(" "),
    print(" "),
    print(" "),

# %%
ar_df.to_csv("arr+tamil_v2.csv", index=False)

# %% [markdown]
# ### data

# %%
metaphors = {
    "data" : [
    {
        "index" : 0,
        "data" : [
            {
                "metaphor": "நள்ளிரவு கைதி இனி நீ",
                "meaning" : "மணதிட்குள் கைதியாக இருக்கிறேன் இரவிலே",
                "tag" : "காதல் வலி",
            },
        ]
    },
    {
        "index" : 1,
        "data" : [
            {
                "metaphor": "தேகம் வெந்து போகும் என",
                "meaning" : "உடல் வழியில் வெந்து போகுமே நீ உண்ணா விட்டால் ",
                "tag" : "காதல்",
            },
        ]
    },
    {
        "index" : 2,
        "data" : [
            {
                "metaphor": "உள்ளம் உரசினால் ஊரரியாதே",
                "meaning" : "இரு உள்ளம் காதல் கொண்டால் ஊர் அறியாது",
                "tag" : "காதல்",
            },
        ]
    },
        {
        "index" : 3,
        "data" : [
            {
                "metaphor": "கம்பன் மகனை தின்ற வார்த்தை",
                "meaning" : "கம்பனின் மகனிட்டு மாணவளியை புண்படும் வார்த்தைகள்",
                "tag" : "கோபம்",
            },
        ]
    },
    {
        "index" : 4,
        "data" : [
            {
                "metaphor": "நீதான் என் தேசிய கீதம்",
                "meaning" : "நீதான் என் உயிர்நாடி உன்னை நினைத்தே பாடுகிறேன் பெண்ணே ",
                "tag" : "ஏக்கம் ",
            },
        ]
    },
        {
        "index" : 5,
        "data" : [
            {
                "metaphor": "மனமொரு திறந்தா புத்தகம் தான்",
                "meaning" : "மனம் என்பது இன்னொருவர் படித்து புரிவதட்கே",
                "tag" : "ஏக்கம்",
            },
        ]
    },
        {
        "index" : 6,
        "data" : [
            {
                "metaphor": "இந்த ஃபஸ்ட்டு நைட்டு என்ன வேஸ்ட்டா",
                "meaning" : "இந்த முதலிரவு வீணாகி விட்டதா லேடி ",
                "tag" : "மகிழ்ச்சி ",
            },
        ]
    },
        {
        "index" : 7,
        "data" : [
            {
                "metaphor": "உதடு கொத்தி உதடு கொத்தி",
                "meaning" : "உன்னை முத்தமிட்டு  உன்னை முத்தமிட்டு ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },
        {
        "index" : 8,
        "data" : [
            {
                "metaphor": "நீ நதி போலே ஓடிக் கொண்டிரு",
                "meaning" : "நீ ஆறு போல நீக்காமல் முன்னேறி கொண்டே இரு மனித",
                "tag" : "முயற்ச்சி",
            },
        ]
    },
        {
        "index" : 9,
        "data" : [
            {
                "metaphor": "உயிரை தொடர்ந்து வரும் நீதானே மெய் எழுத்து ",
                "meaning" : "உயிரெழுத்தை தொடர்ந்து வரும் மே எழுத்து போல ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },
        {
        "index" : 10,
        "data" : [
            {
                "metaphor": "நாடு கடந்து காடு கடந்து மதுரைக்கு வாராக",
                "meaning" : "பயணம் செய்து மதுரை வருகிறார்கள்",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },    {
        "index" : 11,
        "data" : [
            {
                "metaphor": "உலகத்தின் ஆடல் மலர்களுக்கு ஆடையா",
                "meaning" : "பூக்களுக்கு ஆடையாக இருக்கும் நீ தான் உலகத்தின் ஆடை",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },
    {
        "index" : 12,
        "data" : [
            {
                "metaphor": "இலக்கிய மாலை பொழுதினிலே",
                "meaning" : "நல்ல ரசிக்கக்கூடிய மாலை பொழுதினிலே",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 13,
        "data" : [
            {
                "metaphor": "வெண்பனி நீ தூங்கிய புல் வெளி நான்",
                "meaning" : "வெண்பனி போல படந்திருக்கு. புள் வெளி அல்லவே இது ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 14,
        "data" : [
            {
                "metaphor": "ராத்திரி இது எரிகிற ராத்திரி",
                "meaning" : "தன்னால் போல எரிகிறதே இந்த வலி ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 15,
        "data" : [
            {
                "metaphor": "பழி வாங்கவா மெதுவாக",
                "meaning" : "உன்னை குறும்பாக பாலி வாங்கவா",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 16,
        "data" : [
            {
                "metaphor": "பூம்புனலாய் புகுந்ததினால்",
                "meaning" : "புனல் போல என் மேஜில் பாய்த்தினையே ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 17,
        "data" : [
            {
                "metaphor": "காதல் கடன்காரி அடி உலகில்",
                "meaning" : "என் காதலை வாங்கி சென்ற கடன் காரியே பெண்ணே ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 18,
        "data" : [
            {
                "metaphor": "பூ வெடிக்கும் தேன் வடிக்கும்",
                "meaning" : "உன்னை கண்டாலே ஐந்தே பூ தென் வடிக்கும் ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 19,
        "data" : [
            {
                "metaphor": "நீரும் இன்றி வேரும் இன்றி",
                "meaning" : "பாய்ச்ச நீரும் இல்லாமல் வளர வெறும் இல்லாமல் ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 20,
        "data" : [
            {
                "metaphor": "ஆகாயத்தில் நூறு நிலாக்களும்",
                "meaning" : "நூறு நிலா போல வானம் வெளிச்சமாக இருக்கிறதே ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 21,
        "data" : [
            {
                "metaphor": "பஞ்சும் பஞ்சும் சேர்ந்தா தப்பு",
                "meaning" : "காதலனும் நானும் சேர்ந்தால் தப்பாகிவிடும் ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 22,
        "data" : [
            {
                "metaphor": "வானம் பூமி ஆகும் சிறியது",
                "meaning" : "உனது அன்போடு ஒப்பிட்டால் வானம் பூமி சிறிதாக ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 23,
        "data" : [
            {
                "metaphor": "அது அந்த பதவியின் வியாதி",
                "meaning" : "அந்தாள் தொழிலில் இருப்பவனுக்கு வரும் நோய் ",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 24,
        "data" : [
            {
                "metaphor": "சந்தையிலே குண்டுமல்லி",
                "meaning" : "அங்காடியில் குண்டுமல்லி வாங்கவே ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 25,
        "data" : [
            {
                "metaphor": "சொக்கும் படி சிரிச்ச சொன்னபரியா",
                "meaning" : "மனது சொக்கும் படி சிரித்த பெண்ணே ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 26,
        "data" : [
            {
                "metaphor": "தூண்டில் புழுவாய் மங்கை துடித்தாள்",
                "meaning" : "தகோடிலில் மாட்டிய புழு போல துடித்தாள் இவள் ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 27,
        "data" : [
            {
                "metaphor": "உயிலாய் வரைந்தேன் இதிலும்",
                "meaning" : "உயில் போல ஒரு கடிதம் எழுதினேன் ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 28,
        "data" : [
            {
                "metaphor": "எங்கள் விரல்கள் நிலவின் மீது தாளம் போடா",
                "meaning" : "எட்டாத உயரம் அடைய வேண்டுமே நாங்கள் ",
                "tag" : "முயற்ச்சி",
            },
        ]
    },{
        "index" : 29,
        "data" : [
            {
                "metaphor": "கேள்வியாய் வாழ்கிறான் மௌனத்தை",
                "meaning" : "மௌனமாக வாழும் மானிட நீ ஏன்",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 30,
        "data" : [
            {
                "metaphor": "வான தேவதை வந்து சொன்னால்",
                "meaning" : "தேவதை போல வந்து சொன்னாயே",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 31,
        "data" : [
            {
                "metaphor": "கொள்ளும் ஊசி அந்த சங்கதி",
                "meaning" : "ஊசி போல கொள்ளும் அந்த விஷத்தை சொல்லு ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 32,
        "data" : [
            {
                "metaphor": "காதல் ஜாலியில் பாடம் காலி தோழா",
                "meaning" : "காதல் செய்தலில் படிக்காமல் விட்டு விட்டாயே நண்பா ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 33,
        "data" : [
            {
                "metaphor": "தொடாமல் நான் மலர்ந்தேன்",
                "meaning" : "தொடாமல் நான் உருவாக்கினேன் இங்கே ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 34,
        "data" : [
            {
                "metaphor": "சூரிய விளக்கில் சுடர் விடும் கிழக்கு",
                "meaning" : "சூரியன் போல எரிகிறதே இந்த விளக்கு கிழக்கு பக்கமாக ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 35,
        "data" : [
            {
                "metaphor": "நிலா காயும் நேரம் தானே",
                "meaning" : "நிலா வானில் இல்லாத நேரம்தான் ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 36,
        "data" : [
            {
                "metaphor": "மனம் என்ற வீட்டை நீ",
                "meaning" : "மனம் என்பது ஒரு வீடு பொஙறது",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 37,
        "data" : [
            {
                "metaphor": "செல்வ மரம் காய்த்தாலும்",
                "meaning" : "எல்லாம் தரும் செல்வங்கள் வந்தாலும்",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 38,
        "data" : [
            {
                "metaphor": "நீலம் தொயித்த அந்த ஆகாய",
                "meaning" : "நீல நிற ஆகாயமே நீ படர்ந்திருக்கிறாய் ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 39,
        "data" : [
            {
                "metaphor": "மார்பில் ஊறும் உயிரே",
                "meaning" : "என் மார்பிலே வலிந்து செல்லும் உயிரே நீ ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 40,
        "data" : [
            {
                "metaphor": "மார்பில் ஊறும் உயிரே",
                "meaning" : "என் மார்பிலே வலிந்து செல்லும் உயிரே நீ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 41,
        "data" : [
            {
                "metaphor": "தீமைக்கும் கொடுமைக்கும் தீ வெய்க்க சக்தி கொடு",
                "meaning" : "நன்மை தீமை அளிக்க எனக்கு பலம் தா இறைவா ",
                "tag" : "முயற்ச்சி",
            },
        ]
    },{
        "index" : 42,
        "data" : [
            {
                "metaphor": "சட்டென நனைந்தது நெஞ்சம்",
                "meaning" : "சோகத்தில் மனம் வாடிவிட்டதே ",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 43,
        "data" : [
            {
                "metaphor": "ன் ஆசை தாவுது உன் மேலே",
                "meaning" : "உன்னை நோக்கி என் பாசம் எல்லாம் விரிக்கிறதே பெண்ணே",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 44,
        "data" : [
            {
                "metaphor": "வரும் கோவத்தை புன்னகையில்",
                "meaning" : "அவளிட்கு வரும் கோவத்தை புன்னகையில் மறக்கிறாளே",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 45,
        "data" : [
            {
                "metaphor": "நான் முத்தம் தின்பவள்",
                "meaning" : "இவள் ஒரு முத்தத்தை வாய் வழங்குபவள் ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 46,
        "data" : [
            {
                "metaphor": "பன்னீரை மூட்டை கட்டி",
                "meaning" : "பன்னீர் போல அடைத்து செய்து ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 47,
        "data" : [
            {
                "metaphor": "நிலாவை வாங்குவேன்",
                "meaning" : "என் மனதினால் நிலவை வாங்குவேன் ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 48,
        "data" : [
            {
                "metaphor": "பொய்யை நீ விற்றாலும்",
                "meaning" : "பொய் சொல்லாதே என்னிடம்",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 49,
        "data" : [
            {
                "metaphor": "நான் பெத்து இருக்கேன் கட்டு",
                "meaning" : "நான் பெற்று இருக்கிறேன் இந்த கட்டை ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 50,
        "data" : [
            {
                "metaphor": "சேமித்த காதலிது நூறாயிரம்",
                "meaning" : "நிறைய காலமாய் சேமித்தாயே",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 51,
        "data" : [
            {
                "metaphor": "சேமித்த காதலிது நூறாயிரம்",
                "meaning" : "சேமித்த காதலிது நூறாயிரம் தானே ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 52,
        "data" : [
            {
                "metaphor": "பிள்ளையின் சிறுமுக சிரிப்பில்",
                "meaning" : "இந்த பிள்ளையின் சிரிப்பினிலே பெண்ணே ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 53,
        "data" : [
            {
                "metaphor": "மலருமடி உன் கால்கொலுசொலிகள் ",
                "meaning" : "உன் காலில் மலரும் ஐந்தே கொலுசு ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 54,
        "data" : [
            {
                "metaphor": "மறுமுறை ஒரு முறை பார்போமா ",
                "meaning" : "இன்னொரு முறை சந்திப்போன எப்போதாவது ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 55,
        "data" : [
            {
                "metaphor": "தவித்தேன் என் சிறகில்",
                "meaning" : "சிறகில்லா பறவை போல ஒரு சிறகில் தவித்தேன் ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 56,
        "data" : [
            {
                "metaphor": "வெளியே அழுதால் வெட்கம் என்று",
                "meaning" : "தெரியும் படி அழுதாள் நளினமாகி விடுமே என்று ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 57,
        "data" : [
            {
                "metaphor": "மறைத்தாய் பூவின் பின்னால் ஒளிந்தாய்",
                "meaning" : "ளினத்தால் பூவின் பின்னல் ஒளிந்திருந்தாயே",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 58,
        "data" : [
            {
                "metaphor": "இவன் உலகம் தாண்டிய",
                "meaning" : "இவன் எல்லாம் கடந்தவன்",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 59,
        "data" : [
            {
                "metaphor": "நெஞ்சாங்குழியே ஒட்டுதே",
                "meaning" : "கோவத்தில் மண் ஒட்டுகிறதே ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 60,
        "data" : [
            {
                "metaphor": "கொண்டு தான் ருசி அறியும்",
                "meaning" : "அது ருசி சிறிய கால்களை பயன் படுத்தும் ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 61,
        "data" : [
            {
                "metaphor": "வக்கீலே இல்லாமல் வாதாடுவேன்",
                "meaning" : "வாதாடி இல்லாமல் வாதாடி ஜெயிப்பேனே ",
                "tag" : "காதல்",
            },
        ]
    },{
        "index" : 62,
        "data" : [
            {
                "metaphor": "என் தலைவா அகம் அறிவீரோ",
                "meaning" : "எனது மனதை அறிவாரா அவர் ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 63,
        "data" : [
            {
                "metaphor": "மூங்கிலுக்குள் நுழைகின்ற காற்று ",
                "meaning" : "எனக்குள் கோவம் கொந்தளிக்கிறதே ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 64,
        "data" : [
            {
                "metaphor": "சிவப்பு நாக பழ கருப்பு",
                "meaning" : "சிவப்பு நாவல் பலம் போல கருத்தவளே ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 65,
        "data" : [
            {
                "metaphor": "நான் கண்டது ஆறறிவு நீ கொண்டது பேரறிவு",
                "meaning" : "எனக்கோ ஆறறிவு உனக்கு பேரறிவு இருக்கிறது ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 66,
        "data" : [
            {
                "metaphor": "மின்னல் மேல் கோர்ட்டு ",
                "meaning" : "மேகம் எப்போது கேட்டு முன்னது அதுவாக மின்னும்",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 67,
        "data" : [
            {
                "metaphor": "நினைக்குதடி அக்கினி பழமுன்னு",
                "meaning" : "சுடும் பேர் எண்டு தெரிந்திரும் எங்கு கிறதே ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 68,
        "data" : [
            {
                "metaphor": "கலசம்கொண்டு அந்தக் கவசம் உடைத்து",
                "meaning" : "மார்பில் கவசம் அணிந்தேன் ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 69,
        "data" : [
            {
                "metaphor": "தாய்நாட்டைப் பொன்னாக்கு",
                "meaning" : "உன் நாடே செல்வா செழிப்பாக்கு",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 70,
        "data" : [
            {
                "metaphor": "இதற்கு மேல் உறவில்லை ",
                "meaning" : "இதட்கு மேல் ஒண்டும் இல்ல ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 71,
        "data" : [
            {
                "metaphor": "கொன்றை சூடும் கோச்சடையான்",
                "meaning" : "போர் புரியும் கோச்சடையானே ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 72,
        "data" : [
            {
                "metaphor": "இதயத்தின் மொழியால் ",
                "meaning" : "மௌன மொழியாம் இதை மிலோயால் ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 73,
        "data" : [
            {
                "metaphor": "தலையில் முட்டுமே மேகங்கள்",
                "meaning" : "அவ்வளவு உயரம் செல்வாய் நீ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 74,
        "data" : [
            {
                "metaphor": "சிறுகோட்டுப் பெரும்பழம் தூங்கி யாங்கு",
                "meaning" : "சிறு பலம் பெரு கொத்தை நிக்கும் என்பது உண்மையாகும் ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 75,
        "data" : [
            {
                "metaphor": "என் முதுகு தண்டில்",
                "meaning" : "என் றரம்புகளை மின்னல் வெட்டும் ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 76,
        "data" : [
            {
                "metaphor": "வரலாறு பார்போமா கண்ணமா கண்ணமா",
                "meaning" : "வரலாற்றை மீட்டி பார்ப்போமா கன்னம் அக்கண்ணம ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 77,
        "data" : [
            {
                "metaphor": "சோலைக் கிளி சொல்லும்",
                "meaning" : "கிளியின் பாஷையிலே சொல்கிறாயோ ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 78,
        "data" : [
            {
                "metaphor": " கல்லடி படும் என்பதாலே மரம் காய்க்காமல் போவதில்லை",
                "meaning" : "கல்லினால் மானிடர் அடித்து பலம் பரிபார் என்பதட்காக பலம் காய்க்காமல் விடுவதில்லை",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 79,
        "data" : [
            {
                "metaphor": "பருவம் ஒன்று இளமை",
                "meaning" : "இளமை என்பது ஒரு பருவமே ",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 80,
        "data" : [
            {
                "metaphor": "கொஞ்சம் நேரம் என்ன கொல்லையா",
                "meaning" : "கொஞ்ச நேரம் என்னோடு சேர்த்து பிரம்மம்",
                "tag" : "வலி",
            },
        ]
    },{
        "index" : 81,
        "data" : [
            {
                "metaphor": "இல்லை இச்சை நேரம் என்னை",
                "meaning" : "இது என்ன கொஞ்ச நேரமாக இறுக்கியதே",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 82,
        "data" : [
            {
                "metaphor": "சௌக்கியம் அடைவது ஞாயமில்லை",
                "meaning" : "மகிழ்ச்சியாக அடைவது நஜமில்லை",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 83,
        "data" : [
            {
                "metaphor": "மாறுவதெல்லாம் உயிரோடு",
                "meaning" : "எல்லாமே உயிரோடு தானே மாறும்",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 84,
        "data" : [
            {
                "metaphor": "பிறிதோர் பக்கம் மனம் சாயா பிரியம் காப்பேன்",
                "meaning" : "இன்னொரு பக்கம் என் மனம் சாய்த்து",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 85,
        "data" : [
            {
                "metaphor": "இரவெல்லாம் சிறகு விரித்து",
                "meaning" : "இரவுகளில் கதை பேசுங்கள் கிளிகள்",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 86,
        "data" : [
            {
                "metaphor": "மாலை காற்றை தலை கோதி",
                "meaning" : "பின்னேர காற்றிலே தளி கொத்தி செய்யுங்கள்",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 87,
        "data" : [
            {
                "metaphor": "முகிலாய் இருந்தேன் மழையாய் செய்தாய்",
                "meaning" : "முகில் போல இருந்த என்னை மலை பல செய்து விட்டாயே ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 88,
        "data" : [
            {
                "metaphor": "முள்ளில் நீ மெத்தை",
                "meaning" : "ஏன் முள் மெத்தையில் தூங்குகிறாய்",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 89,
        "data" : [
            {
                "metaphor": "உலகங்கள் ஏழும் பனி மூடும் போதும்",
                "meaning" : "அணைத்து உலகும் பணியாள் மூடும் பொது ",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 90,
        "data" : [
            {
                "metaphor": "அது நூறு கிச்சு ஆகுதான்னு பாப்போம் வா",
                "meaning" : "இந்த காதல் ஆறு நூறாக மாறுகிறதா என்று பாப்போம் வா",
                "tag" : "மகிழ்ச்சி",
            },
        ]
    },{
        "index" : 91,
        "data" : [
            {
                "metaphor": "லோகம் வைத்தம் காதல் அத்வைத்தம்",
                "meaning" : "காதல் வைத்தும் லோகம் வைத்தும் ",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 92,
        "data" : [
            {
                "metaphor": "கம்மா கரையிலே உம்மா கொடுக்கவா சும்மா நீ வெளுத்துக்கட்டு",
                "meaning" : "உனக்கு முத்தம் அளிக்கவே அந்த ஆற்று கரையிலே ",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 93,
        "data" : [
            {
                "metaphor": "ன்னகைக்கும் புலிகளுண்டு",
                "meaning" : "நயவங்கக்கா மனிதர்களும் உண்டு ",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 94,
        "data" : [
            {
                "metaphor": "உயிர் காதலே",
                "meaning" : "என் உயிர் காதலே ",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 95,
        "data" : [
            {
                "metaphor": "கண்ணில் ஒன்றை பிச்சைப்போட்டு போடி",
                "meaning" : "உன் கண்ணினால் எனக்கு பிச்சை போவாய்",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 96,
        "data" : [
            {
                "metaphor": "கடலின் மேலே ஒட்டகம் நடக்கும்",
                "meaning" : "நீ மனம் வைத்தால் நடக்காததும் நடக்கும் இவ் உலகத்திலே ",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 97,
        "data" : [
            {
                "metaphor": "நானில்லை என் வசம் ",
                "meaning" : "நான் நானாக இல்லையே",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 98,
        "data" : [
            {
                "metaphor": "ஒளியே வழியாக",
                "meaning" : "இழி விளக்காக வருவியே",
                "tag" : "ஏக்கம்",
            },
        ]
    },{
        "index" : 99,
        "data" : [
            {
                "metaphor": "காதல் பார்வையே போதுமே",
                "meaning" : "உன் காதல் பார்வை ஒன்றே போதுமே",
                "tag" : "ஏக்கம்",
            },
        ]
    }
    ]
}

# %% [markdown]
# ### engine

# %%
import random

arr = []
uruvagam = ["தொகையுருவகம்",
"விரியுருவகம்",
"தொகைவிரியுருவகம்",
"இயைபுருவகம்",
"இயைபிலியுருவகம்",
"வியனிலையுருவகம்",
"சிறப்புருவகம்",
"விரூபக உருவகம்",
"சமாதான உருவகம்",
"உருவக உருவகம்",
"ஏகாங்க உருவகம்",
"அநேகாங்கயுருவகம்",
"முற்றுருவகம்",
"அவயவ உருவகம்",
"அவயவி உருவகம்"]

c= 0
for idx,ele in enumerate(metaphors["data"]):
    if idx == c:
        arr.append([ele["data"][0]["metaphor"], ele["data"][0]["meaning"], ele["data"][0]["tag"], uruvagam[random.randint(0,14)] ])
        c += 1

# %%
meta = pd.DataFrame(
    arr,
    columns=["m1", "m1_meaning","m1_tag","m1_type"]
)

# %%
new_pd = pd.concat([ar_df, meta], axis=1)

# %%
new_pd.columns
# Out:
# Index(['lyricist', 'movie', 'song_name', 'year', 'lyrics_english',
#        'lyrics_tamil', 'music_director', 'link', 'm1', 'm1_meaning', 'm1_tag',
#        'm1_type'],
#       dtype='object')

# %%
cols1 = ['movie', 'song_name',"lyricist",'year', 'music_director','lyrics_tamil','m1', 'm1_meaning', 'm1_tag','m1_type']
new_pd = new_pd[cols1]

# %%
df3 = pd.read_csv("180565J_IR_Corpus_v3.csv")

# %%
df3[0:5]
# Out:
#                movie               song_name lyricist    year  \
# 0  பார்த்தாலே பரவசம்          அதிசய திருமணம்     வாலி  2001.0
# 1         சக்கரகட்டி         மருதாணி மருதாணி     வாலி  2007.0
# 2  பார்த்தாலே பரவசம்             மன்மத மாசம்     வாலி  2001.0
# 3  பார்த்தாலே பரவசம்            மூன்றெழுத்து     வாலி  2001.0
# 4  பார்த்தாலே பரவசம்  நீதான் என் தேசிய கீதம்     வாலி  2001.0
#
#     music_director                                       lyrics_tamil  \
# 0  ஏ. ஆர். ரகுமான்  அதிசய திருமணம் \n ஆனந்த திருமணம் \n அருள்மிகு ...
# 1  ஏ. ஆர். ரகுமான்  மருதாணி மருதாணி \n மருதாணி விழியில் என் \n அடி...
# 2  ஏ. ஆர். ரகுமான்  மன்மத மாசம் \n இது மன்மத மாசம் \n மன்மத மாசம்…...
# 3  ஏ. ஆர். ரகுமான்  ஹே குருவே \n குருவே குருவே \n குருவே குருவே \n...
# 4  ஏ. ஆர். ரகுமான்  காதலே ஜெயம் \nநீதான் என் தேசிய \n கீதம் ரஞ்சனே...
#
#                            m1  \
# 0        நள்ளிரவு கைதி இனி நீ
# 1      தேகம் வெந்து போகும் என
# 2    உள்ளம் உரசினால் ஊரரியாதே
# 3  கம்பன் மகனை தின்ற வார்த்தை
# ...
